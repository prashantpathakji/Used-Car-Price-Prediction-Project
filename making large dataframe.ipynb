# %% [markdown]
# # Let's make a large dataframe using screped small detasets:

# %%
import pandas as pd
cars_df=pd.concat(map(pd.read_csv, ['df01', 'df02','df03','df04']), ignore_index=True)
cars_df
# Out:
#       Unnamed: 0          Brand        Model with Variant  Manufacturing Year  \
# 0              0     Volkswagen                  ['Polo']              2013.0
# 1              1          Honda                   ['WRV']              2020.0
# 2              2  Mercedes-Benz               ['C-Class']              2022.0
# 3              3         Maruti       ['Suzuki', 'Swift']              2019.0
# 4              4         Maruti     ['Suzuki', 'Wagon-R']              2016.0
# ...          ...            ...                       ...                 ...
# 5328         435        Hyundai                ['Santro']              2001.0
# 5329         436         Maruti       ['Suzuki', 'Swift']              2006.0
# 5330         437         Maruti  ['Suzuki', 'Zen-Estilo']              2007.0
# 5331         438        Hyundai        ['Santro', 'Xing']              2009.0
# 5332         439         Maruti        ['Suzuki', 'Omni']              2009.0
#
# ...

# %%
cars_df.to_csv("cars_df")
