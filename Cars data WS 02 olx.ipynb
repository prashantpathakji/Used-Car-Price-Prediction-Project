# %% [markdown]
# # Setup:

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time

# %% [markdown]
# # Df4:

# %%
chrome_path = r"C:\Users\Prashant Pathak\Desktop\chromedriver.exe"
driver = webdriver.Chrome(chrome_path)
driver.implicitly_wait(1)



driver.maximize_window()

driver.get("https://www.olx.in/cars_c84?filter=first_owner_eq_1%2Cpetrol_eq_diesel")


for i in range(10):
    driver.execute_script("window.scrollBy(0, 300)")
    driver.find_element(By.XPATH,'//div[@class="_38O09"]').click()
    time.sleep(3)


# Brand Name:
brand=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2Gr10"]')
for i in dt:
    brand.append(i.text.split(" ")[0])
    
    

# Model name with Variant:
model_var=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2Gr10"]')
for i in dt:
    model_var.append(i.text.split(" ")[1:])
    
    
# Manufaturing Year:    
year=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_21gnE"]')
for i in dt:
    year.append(i.text.split(" ")[0])
    
# Driven KilometerS:    
driven_km=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2v8Tq"]')
for i in dt:
    driven_km.append(i.text.split(" ")[3])
    
    
    
# Locetion:
loc=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_3VRSm"]')
for i in dt:
    loc.append(i.text.split("\n")[0])  


    
# Price:
price=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2v8Tq"]')
for i in dt:
    price.append((i.text.split("\n")[0]).split(" ")[1])
    
    
    
print(len(brand),
len(model_var),
len(year),
len(driven_km),
len(loc),
len(price))
# Out:
# 436 436 436 436 436 436

# %%
#Fuel Type:    (manualCheck)
fuel=[]
for i in range(436):
    i="Diesel"
    fuel.append(i)
    

# Number of owner: (manualCheck)
owner=[]
for i in range(436):
    i="First"
    owner.append(i)
    
print(len(fuel),len(owner))
# Out:
# 436 436

# %%
df4=pd.DataFrame({"Brand":brand,"Model with Variant":model_var,"Manufacturing Year":year,"Driven KM":driven_km,"Fuel Type":fuel,"No. of Owner":owner,"Locetion":loc,"Price":price})
df4
# Out:
#        Brand      Model with Variant Manufacturing Year Driven KM Fuel Type  \
# 0    Hyundai                 [Xcent]               2017    54,000    Diesel
# 1     Toyota              [Fortuner]               2012    96,000    Diesel
# 2    Renault                [Duster]               2017  128000.0    Diesel
# 3    Hyundai                 [Verna]               2018   120,000    Diesel
# 4    Hyundai                 [Creta]               2020    50,000    Diesel
# ..       ...                     ...                ...       ...       ...
# 431    Honda                 [Amaze]               2014   57444.0    Diesel
# 432   Maruti  [Suzuki, Swift, Dzire]               2013   58988.0    Diesel
# 433   Toyota                [Innova]               2016   121,524    Diesel
# 434     Tata                  [Hexa]               2018    88,726    Diesel
# 435  Hyundai                 [Creta]               2020    60,000    Diesel
#
#     No. of Owner          Locetion      Price
# ...

# %%
driver.close()

# %% [markdown]
# # Df5:

# %%
chrome_path = r"C:\Users\Prashant Pathak\Desktop\chromedriver.exe"
driver = webdriver.Chrome(chrome_path)
driver.implicitly_wait(2)



driver.maximize_window()

driver.get("https://www.olx.in/cars_c84?filter=first_owner_eq_2%2Cpetrol_eq_diesel")


for i in range(10):
    driver.execute_script("window.scrollBy(0, 300)")
    driver.find_element(By.XPATH,'//div[@class="_38O09"]').click()
    time.sleep(3)


# Brand Name:
brand=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2Gr10"]')
for i in dt:
    brand.append(i.text.split(" ")[0])
    
    

# Model name with Variant:
model_var=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2Gr10"]')
for i in dt:
    model_var.append(i.text.split(" ")[1:])
    
    
# Manufaturing Year:    
year=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_21gnE"]')
for i in dt:
    year.append(i.text.split(" ")[0])
    
# Driven KilometerS:    
driven_km=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2v8Tq"]')
for i in dt:
    driven_km.append(i.text.split(" ")[3:4])
    
    
    
# Locetion:
loc=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_3VRSm"]')
for i in dt:
    loc.append(i.text.split("\n")[0])  


    
# Price:
price=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2v8Tq"]')
for i in dt:
    price.append((i.text.split("\n")[0]).split(" ")[1])
    
    
    
print(len(brand),
len(model_var),
len(year),
len(driven_km),
len(loc),
len(price))
# Out:
# 439 439 439 439 439 439

# %%
#Fuel Type:    (manualCheck)
fuel=[]
for i in range(439):
    i="Diesel"
    fuel.append(i)
    

# Number of owner: (manualCheck)
owner=[]
for i in range(439):
    i="Second"
    owner.append(i)
    
print(len(fuel),len(owner))
# Out:
# 439 439

# %%
df5=pd.DataFrame({"Brand":brand,"Model with Variant":model_var,"Manufacturing Year":year,"Driven KM":driven_km,"Fuel Type":fuel,"No. of Owner":owner,"Locetion":loc,"Price":price})
df5
# Out:
#           Brand Model with Variant Manufacturing Year  Driven KM Fuel Type  \
# 0         Volvo              [S60]               2011   [85,000]    Diesel
# 1      Mahindra           [XUV500]               2014  [95344.0]    Diesel
# 2          Tata   [Safari, Storme]               2015   [81,000]    Diesel
# 3       Hyundai            [Verna]               2015   [71,755]    Diesel
# 4       Hyundai     [Xcent, Prime]               2018  [120,000]    Diesel
# ..          ...                ...                ...        ...       ...
# 434   Chevrolet            [Cruze]               2011  [110,000]    Diesel
# 435  Volkswagen             [Polo]               2012   [79,000]    Diesel
# 436   Chevrolet            [Cruze]               2014   [78,000]    Diesel
# 437     Hyundai              [i20]               2012   [60,000]    Diesel
# 438     Hyundai              [i20]               2016   [68,000]    Diesel
#
#     No. of Owner       Locetion      Price
# ...

# %%
driver.close()

# %% [markdown]
# # Df6:

# %%
chrome_path = r"C:\Users\Prashant Pathak\Desktop\chromedriver.exe"
driver = webdriver.Chrome(chrome_path)
driver.implicitly_wait(2)



driver.maximize_window()

driver.get("https://www.olx.in/cars_c84?filter=first_owner_eq_2%2Cpetrol_eq_diesel")


for i in range(10):
    driver.execute_script("window.scrollBy(0, 300)")
    driver.find_element(By.XPATH,'//div[@class="_38O09"]').click()
    time.sleep(3)


# Brand Name:
brand=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2Gr10"]')
for i in dt:
    brand.append(i.text.split(" ")[0])
    
    

# Model name with Variant:
model_var=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2Gr10"]')
for i in dt:
    model_var.append(i.text.split(" ")[1:])
    
    
# Manufaturing Year:    
year=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_21gnE"]')
for i in dt:
    year.append(i.text.split(" ")[0])
    
# Driven KilometerS:    
driven_km=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2v8Tq"]')
for i in dt:
    driven_km.append(i.text.split(" ")[3:4])
    
    
    
# Locetion:
loc=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_3VRSm"]')
for i in dt:
    loc.append(i.text.split("\n")[0])  


    
# Price:
price=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2v8Tq"]')
for i in dt:
    price.append((i.text.split("\n")[0]).split(" ")[1])
    
    
    
print(len(brand),
len(model_var),
len(year),
len(driven_km),
len(loc),
len(price))
# Out:
# 439 439 439 439 439 439

# %%
#Fuel Type:    (manualCheck)
fuel=[]
for i in range(439):
    i="Diesel"
    fuel.append(i)
    

# Number of owner: (manualCheck)
owner=[]
for i in range(439):
    i="Third"
    owner.append(i)
    
print(len(fuel),len(owner))
# Out:
# 439 439

# %%
df6=pd.DataFrame({"Brand":brand,"Model with Variant":model_var,"Manufacturing Year":year,"Driven KM":driven_km,"Fuel Type":fuel,"No. of Owner":owner,"Locetion":loc,"Price":price})
df6
# Out:
#              Brand Model with Variant Manufacturing Year   Driven KM  \
# 0               MG     [Hector, Plus]               2021    [23,609]
# 1           Toyota         [Fortuner]               2012  [138713.0]
# 2    Mercedes-Benz          [E-Class]               2015    [82,000]
# 3             Ford           [Fiesta]               2011    [71,000]
# 4           Maruti   [Suzuki, Esteem]               2005   [120,000]
# ..             ...                ...                ...         ...
# 434       Mahindra           [Bolero]               2009   [110,000]
# 435         Toyota      [Etios, Liva]               2012   [100,000]
# 436      Chevrolet      [Tavera, Neo]               2008   [310,000]
# 437       Mahindra           [XUV500]               2013    [55,180]
# 438          Honda             [City]               2016    [43,265]
#
#     Fuel Type No. of Owner            Locetion      Price
# 0      Diesel        Third             Manipal  22,00,000
# ...

# %%
driver.close()

# %%
df02=pd.concat([df4,df5,df6])
df02
# Out:
#          Brand Model with Variant Manufacturing Year  Driven KM Fuel Type  \
# 0      Hyundai            [Xcent]               2017     54,000    Diesel
# 1       Toyota         [Fortuner]               2012     96,000    Diesel
# 2      Renault           [Duster]               2017   128000.0    Diesel
# 3      Hyundai            [Verna]               2018    120,000    Diesel
# 4      Hyundai            [Creta]               2020     50,000    Diesel
# ..         ...                ...                ...        ...       ...
# 434   Mahindra           [Bolero]               2009  [110,000]    Diesel
# 435     Toyota      [Etios, Liva]               2012  [100,000]    Diesel
# 436  Chevrolet      [Tavera, Neo]               2008  [310,000]    Diesel
# 437   Mahindra           [XUV500]               2013   [55,180]    Diesel
# 438      Honda             [City]               2016   [43,265]    Diesel
#
#     No. of Owner          Locetion      Price
# ...

# %%
df02.to_csv("df02")

# %%
driven_km=[]
dt=driver.find_elements(By.XPATH,'//div[@class="_2v8Tq"]')
for i in dt:
    driven_km.append(i.text.split(" ")[3:4])

# %%
print(driven_km)
# Out:
# [['198,000'], ['61000.0'], ['43,000'], ['90,000'], ['70,000'], ['100,000'], ['50,000'], ['220,000'], ['148,000'], ['145,000'], ['114686.0'], ['90,000'], ['62,000'], ['300,000'], ['30,000'], ['58,000'], ['98000.0'], ['57000.0'], ['122000.0'], ['123,000'], ['116,000'], ['45000.0'], ['33,000'], ['999,999'], ['40,000'], ['10000.0'], ['56,000'], ['150,000'], ['66,000'], ['83,000'], ['179,000'], ['170000.0'], ['119000.0'], ['60000.0'], ['52000.0'], ['50,000'], ['70000.0'], ['78000.0'], ['850,000'], ['210000.0'], ['310,000'], ['55,000'], ['80000.0'], ['162,000'], ['70,000'], ['92000.0'], ['49000.0'], ['80000.0'], ['65000.0'], ['88000.0'], ['125000.0'], ['86000.0'], ['71000.0'], ['90000.0'], ['78000.0'], ['125000.0'], ['42,000'], ['69269.0'], ['275,251'], ['127,200'], ['54,455'], ['78,000'], ['87000.0'], ['70,000'], ['90,000'], ['86,000'], ['114,000'], ['98000.0'], ['140,000'], ['74272.0'], ['84,145'], ['79000.0'], ['75,000'], ['106000.0'], ['69000.0'], ['136000.0'], ['63000.0'], ['105,000']
# ...
